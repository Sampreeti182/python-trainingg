# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.functions import col, sum, avg, dense_rank,try_to_timestamp,lit,coalesce,initcap,lower,trim
from pyspark.sql.types import *
from pyspark.sql.window import Window

# %%
spark=SparkSession.builder.appName('Marketplace Orders').getOrCreate()

# %%
orders_data = [
    ("ORD001","C001","Delhi ","Electronics","Laptop","45000","2024-01-05","Completed"),
    ("ORD002","C002","Mumbai","Electronics","Mobile ","32000","05/01/2024","Completed"),
    ("ORD003","C003","Bangalore","Electronics","Tablet","30000","2024/01/06","Completed"),
    ("ORD004","C004","Delhi","Electronics","Laptop","","2024-01-07","Cancelled"),
    ("ORD005","C005","Chennai","Electronics","Mobile","invalid","2024-01-08","Completed"),
    ("ORD006","C006","Mumbai","Home","Mixer",None,"2024-01-08","Completed"),
    ("ORD007","C001","Delhi","Electronics","Laptop","47000","09-01-2024","Completed"),
    ("ORD008","C007","Bangalore","Home","Vacuum","28000","2024-01-09","Completed"),
    ("ORD009","C002","Mumbai","Electronics","Laptop","55000","2024-01-10","Completed"),
    ("ORD010","C008","Delhi","Home","AirPurifier","38000","2024-01-10","Completed"),
    ("ORD011","C009","Mumbai","Home","Vacuum","29000","2024-01-11","Completed"),
    ("ORD012","C010","Bangalore","Electronics","Mobile","33000","2024-01-11","Completed"),
    ("ORD013","C003","Bangalore","Home","Mixer","21000","2024-01-12","Completed"),
    ("ORD014","C004","Delhi","Electronics","Tablet","26000","2024-01-12","Completed"),
    ("ORD015","C005","Chennai","Electronics","Laptop","62000","2024-01-13","Completed"),
    ("ORD016","C006","Mumbai","Home","AirPurifier","40000","2024-01-13","Completed"),
    ("ORD017","C007","Bangalore","Electronics","Laptop","51000","2024-01-14","Completed"),
    ("ORD018","C008","Delhi","Home","Vacuum","31000","2024-01-14","Completed"),
    ("ORD019","C009","Mumbai","Electronics","Tablet","29000","2024-01-15","Completed"),
    ("ORD020","C010","Bangalore","Electronics","Laptop","54000","2024-01-15","Completed"),
    ("ORD020","C010","Bangalore","Electronics","Laptop","54000","2024-01-15","Completed")
]

# %% [markdown]
# PHASE 1 — SCHEMA & INGESTION
# Define an explicit schema

# %%
schema = StructType([
    StructField("order_id", StringType(), True),
    StructField("customer_id", StringType(), True),
    StructField("city", StringType(), True),
    StructField("category", StringType(), True),
    StructField("product", StringType(), True),
    StructField("amount", StringType(), True),
    StructField("order_date", StringType(), True),
    StructField("status", StringType(), True)
])

# %% [markdown]
# Create a DataFrame using the schema

# %%
df_raw=spark.createDataFrame(data=orders_data,schema=schema)

# %% [markdown]
# Print and verify schema

# %%
df_raw.printSchema()
df_raw.show(truncate=False)
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- amount: string (nullable = true)
#  |-- order_date: string (nullable = true)
#  |-- status: string (nullable = true)
#
# +--------+-----------+---------+-----------+-----------+-------+----------+---------+
# |order_id|customer_id|city     |category   |product    |amount |order_date|status   |
# +--------+-----------+---------+-----------+-----------+-------+----------+---------+
# |ORD001  |C001       |Delhi    |Electronics|Laptop     |45000  |2024-01-05|Completed|
# |ORD002  |C002       |Mumbai   |Electronics|Mobile     |32000  |05/01/2024|Completed|
# |ORD003  |C003       |Bangalore|Electronics|Tablet     |30000  |2024/01/06|Completed|
# |ORD004  |C004       |Delhi    |Electronics|Laptop     |       |2024-01-07|Cancelled|
# |ORD005  |C005       |Chennai  |Electronics|Mobile     |invalid|2024-01-08|Completed|
# |ORD006  |C006       |Mumbai   |Home       |Mixer      |NULL   |2024-01-08|Completed|
# |ORD007  |C001       |Delhi    |Electronics|Laptop     |47000  |09-01-2024|Completed|
# |ORD008  |C007       |Bangalore|Home       |Vacuum     |28000  |2024-01-09|Completed|
# |ORD009  |C002       |Mumbai   |Electronics|Laptop     |55000  |2024-01-10|Completed|
# |ORD010  |C008       |Delhi    |Home       |AirPurifier|38000  |2024-01-10|Completed|
# |ORD011  |C009       |Mumbai   |Home       |Vacuum     |29000  |2024-01-11|Completed|
# |ORD012  |C010       |Bangalore|Electronics|Mobile     |33000  |2024-01-11|Completed|
# |ORD013  |C003       |Bangalore|Home       |Mixer      |21000  |2024-01-12|Completed|
# |ORD014  |C004       |Delhi    |Electronics|Tablet     |26000  |2024-01-12|Completed|
# |ORD015  |C005       |Chennai  |Electronics|Laptop     |62000  |2024-01-13|Completed|
# |ORD016  |C006       |Mumbai   |Home       |AirPurifier|40000  |2024-01-13|Completed|
# |ORD017  |C007       |Bangalore|Electronics|Laptop     |51000  |2024-01-14|Completed|
# |ORD018  |C008       |Delhi    |Home       |Vacuum     |31000  |2024-01-14|Completed|
# |ORD019  |C009       |Mumbai   |Electronics|Tablet     |29000  |2024-01-15|Completed|
# |ORD020  |C010       |Bangalore|Electronics|Laptop     |54000  |2024-01-15|Completed|
# +--------+-----------+---------+-----------+-----------+-------+----------+---------+
# only showing top 20 rows

# %% [markdown]
# PHASE 2 — DATA CLEANING
# Trim all string columns

# %%
for c in df_raw.columns:
    df_raw=df_raw.withColumn(c,trim(df_raw[c]))

# %% [markdown]
# Standardize city , category , and product values

# %%
df_clean=df_raw\
.withColumn("city",initcap(lower(col("city"))))\
.withColumn("category",initcap(lower(col("category"))))\
.withColumn("product",initcap(lower(col("product"))))

# %% [markdown]
# Convert amount to IntegerType

# %%
df_clean=df_clean.withColumn(
    "amount",
    when(col("amount").rlike(r'^[0-9]+$'),col("amount").cast(IntegerType()))\
    .otherwise(None)
)

# %% [markdown]
# Handle invalid, empty, and null amount values

# %%
df_clean=df_clean.filter(col("amount").isNotNull())

# %% [markdown]
# Convert order_date into DateType (handle multiple formats)

# %%
df_clean=df_clean.withColumn(
    "order_date",
    coalesce(
        try_to_timestamp(col("order_date"), lit("yyyy-MM-dd")),
        try_to_timestamp(col("order_date"), lit("dd-MM-yyyy")),
        try_to_timestamp(col("order_date"), lit("MM-dd-yyyy")),
        try_to_timestamp(col("order_date"), lit("dd/MM/yyyy")),
        try_to_timestamp(col("order_date"), lit("MM/dd/yyyy")),
        try_to_timestamp(col("order_date"), lit("yyyy/MM/dd"))
    ).cast(DateType())
)

# %% [markdown]
# Remove duplicate order_id records

# %%
df_clean=df_clean.dropDuplicates(["order_id"])

# %% [markdown]
# Keep only Completed orders

# %%
df_clean=df_clean.filter(col("status")=="Completed")

# %% [markdown]
# PHASE 3 — DATA VALIDATION
# Count records before and after cleaning

# %%
print("Before: ", df_raw.count())
print("After: ", df_clean.count())
# Out:
# Before:  21
# After:  17

# %% [markdown]
# Verify no nulls in order_id , amount , and order_date

# %%
df_clean.select([
    count(when(col(c).isNull(),"*")).alias(c) for c in df_clean.columns
])
# Out:
# DataFrame[order_id: bigint, customer_id: bigint, city: bigint, category: bigint, product: bigint, amount: bigint, order_date: bigint, status: bigint]

# %% [markdown]
# Confirm correct data types

# %%
df_clean.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- amount: integer (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- status: string (nullable = true)

# %% [markdown]
# PHASE 4 — ANALYTICS & AGGREGATIONS
# Total revenue per city

# %%
city_revenue=df_clean.groupBy("city").agg(
    sum("amount").alias("total_revenue")
)
city_revenue.show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |Bangalore|       217000|
# |  Chennai|        62000|
# |   Mumbai|       185000|
# |    Delhi|       187000|
# +---------+-------------+

# %% [markdown]
# Total revenue per category

# %%
category_revenue=df_clean.groupBy("category").agg(
    sum("amount").alias("total_revenue")
)
category_revenue.show()
# Out:
# +-----------+-------------+
# |   category|total_revenue|
# +-----------+-------------+
# |       Home|       187000|
# |Electronics|       464000|
# +-----------+-------------+

# %% [markdown]
# Total revenue per product

# %%
product_revenue=df_clean.groupBy("product").agg(
    sum("amount").alias("total_revenue")
)
product_revenue.show()
# Out:
# +-----------+-------------+
# |    product|total_revenue|
# +-----------+-------------+
# |     Vacuum|        88000|
# |Airpurifier|        78000|
# |     Laptop|       314000|
# |      Mixer|        21000|
# |     Mobile|        65000|
# |     Tablet|        85000|
# +-----------+-------------+

# %% [markdown]
# Average order value per city

# %%
avg_order_city=df_clean.groupBy("city").agg(
    avg("amount").alias("avg_order_value")
)
avg_order_city.show()
# Out:
# +---------+------------------+
# |     city|   avg_order_value|
# +---------+------------------+
# |Bangalore|36166.666666666664|
# |  Chennai|           62000.0|
# |   Mumbai|           37000.0|
# |    Delhi|           37400.0|
# +---------+------------------+

# %% [markdown]
# Identify top 3 products by revenue

# %%
top_products=product_revenue.orderBy(col("total_revenue").desc()).limit(3)
top_products.show()
# Out:
# +-------+-------------+
# |product|total_revenue|
# +-------+-------------+
# | Laptop|       314000|
# | Vacuum|        88000|
# | Tablet|        85000|
# +-------+-------------+

# %% [markdown]
# PHASE 5 — WINDOW FUNCTIONS
# Rank cities by total revenue

# %%
city_window=Window.orderBy(col("total_revenue").desc())
city_rank=city_revenue\
.withColumn("rank",dense_rank().over(city_window))
city_rank.show()
# Out:
# +---------+-------------+----+
# |     city|total_revenue|rank|
# +---------+-------------+----+
# |Bangalore|       217000|   1|
# |    Delhi|       187000|   2|
# |   Mumbai|       185000|   3|
# |  Chennai|        62000|   4|
# +---------+-------------+----+

# %% [markdown]
# Rank products within each category by revenue

# %%
cat_prod_window=Window.partitionBy("category").orderBy(col("total_revenue").desc())
product_rank=df_clean.groupBy("category","product").agg(
    sum("amount").alias("total_revenue"))\
    .withColumn("rank",dense_rank().over(cat_prod_window))
product_rank.show()
# Out:
# +-----------+-----------+-------------+----+
# |   category|    product|total_revenue|rank|
# +-----------+-----------+-------------+----+
# |Electronics|     Laptop|       314000|   1|
# |Electronics|     Tablet|        85000|   2|
# |Electronics|     Mobile|        65000|   3|
# |       Home|     Vacuum|        88000|   1|
# |       Home|Airpurifier|        78000|   2|
# |       Home|      Mixer|        21000|   3|
# +-----------+-----------+-------------+----+

# %% [markdown]
# Identify the top product per category

# %%
top_product_category=product_rank.filter(col("rank")==1)
top_product_category.show()
# Out:
# +-----------+-------+-------------+----+
# |   category|product|total_revenue|rank|
# +-----------+-------+-------------+----+
# |Electronics| Laptop|       314000|   1|
# |       Home| Vacuum|        88000|   1|
# +-----------+-------+-------------+----+

# %% [markdown]
# PHASE 6 — PERFORMANCE AWARENESS
# Cache the cleaned DataFrame

# %%
df_clean.cache()
# Out:
# DataFrame[order_id: string, customer_id: string, city: string, category: string, product: string, amount: int, order_date: date, status: string]

# %%
df_clean.count()
# Out:
# 17

# %% [markdown]
# Run multiple aggregations and observe behavior

# %%
city_revenue.show()
category_revenue.show()
product_revenue.show()
# Out:
# +---------+-------------+
# |     city|total_revenue|
# +---------+-------------+
# |    Delhi|       187000|
# |Bangalore|       217000|
# |   Mumbai|       185000|
# |  Chennai|        62000|
# +---------+-------------+
#
# +-----------+-------------+
# |   category|total_revenue|
# +-----------+-------------+
# |       Home|       187000|
# |Electronics|       464000|
# +-----------+-------------+
#
# +-----------+-------------+
# |    product|total_revenue|
# +-----------+-------------+
# |     Vacuum|        88000|
# |     Laptop|       314000|
# |     Tablet|        85000|
# |     Mobile|        65000|
# |Airpurifier|        78000|
# |      Mixer|        21000|
# +-----------+-------------+

# %% [markdown]
# Use explain(True) to inspect shuffle and execution plan

# %%
df_clean.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'Filter '`=`('status, Completed)
# +- Deduplicate [order_id#33]
#    +- Project [order_id#33, customer_id#34, city#41, category#42, product#43, amount#44, cast(coalesce(try_to_timestamp(order_date#39, Some(yyyy-MM-dd), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(dd-MM-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(MM-dd-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(dd/MM/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(MM/dd/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(yyyy/MM/dd), TimestampType, Some(Etc/UTC), false)) as date) AS order_date#45, status#40]
#       +- Filter isnotnull(amount#44)
#          +- Project [order_id#33, customer_id#34, city#41, category#42, product#43, CASE WHEN RLIKE(amount#38, ^[0-9]+$) THEN cast(amount#38 as int) ELSE cast(null as int) END AS amount#44, order_date#39, status#40]
#             +- Project [order_id#33, customer_id#34, city#41, category#42, initcap(lower(product#37)) AS product#43, amount#38, order_date#39, status#40]
#                +- Project [order_id#33, customer_id#34, city#41, initcap(lower(category#36)) AS category#42, product#37, amount#38, order_date#39, status#40]
#                   +- Project [order_id#33, customer_id#34, initcap(lower(city#35)) AS city#41, category#36, product#37, amount#38, order_date#39, status#40]
#                      +- Project [order_id#33, customer_id#34, city#35, category#36, product#37, amount#38, order_date#39, trim(status#7, None) AS status#40]
#                         +- Project [order_id#33, customer_id#34, city#35, category#36, product#37, amount#38, trim(order_date#6, None) AS order_date#39, status#7]
#                            +- Project [order_id#33, customer_id#34, city#35, category#36, product#37, trim(amount#5, None) AS amount#38, order_date#6, status#7]
#                               +- Project [order_id#33, customer_id#34, city#35, category#36, trim(product#4, None) AS product#37, amount#5, order_date#6, status#7]
#                                  +- Project [order_id#33, customer_id#34, city#35, trim(category#3, None) AS category#36, product#4, amount#5, order_date#6, status#7]
#                                     +- Project [order_id#33, customer_id#34, trim(city#2, None) AS city#35, category#3, product#4, amount#5, order_date#6, status#7]
#                                        +- Project [order_id#33, trim(customer_id#1, None) AS customer_id#34, city#2, category#3, product#4, amount#5, order_date#6, status#7]
#                                           +- Project [trim(order_id#0, None) AS order_id#33, customer_id#1, city#2, category#3, product#4, amount#5, order_date#6, status#7]
#                                              +- LogicalRDD [order_id#0, customer_id#1, city#2, category#3, product#4, amount#5, order_date#6, status#7], false
#
# == Analyzed Logical Plan ==
# order_id: string, customer_id: string, city: string, category: string, product: string, amount: int, order_date: date, status: string
# Filter (status#40 = Completed)
# +- Deduplicate [order_id#33]
#    +- Project [order_id#33, customer_id#34, city#41, category#42, product#43, amount#44, cast(coalesce(try_to_timestamp(order_date#39, Some(yyyy-MM-dd), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(dd-MM-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(MM-dd-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(dd/MM/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(MM/dd/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(yyyy/MM/dd), TimestampType, Some(Etc/UTC), false)) as date) AS order_date#45, status#40]
#       +- Filter isnotnull(amount#44)
#          +- Project [order_id#33, customer_id#34, city#41, category#42, product#43, CASE WHEN RLIKE(amount#38, ^[0-9]+$) THEN cast(amount#38 as int) ELSE cast(null as int) END AS amount#44, order_date#39, status#40]
#             +- Project [order_id#33, customer_id#34, city#41, category#42, initcap(lower(product#37)) AS product#43, amount#38, order_date#39, status#40]
#                +- Project [order_id#33, customer_id#34, city#41, initcap(lower(category#36)) AS category#42, product#37, amount#38, order_date#39, status#40]
#                   +- Project [order_id#33, customer_id#34, initcap(lower(city#35)) AS city#41, category#36, product#37, amount#38, order_date#39, status#40]
#                      +- Project [order_id#33, customer_id#34, city#35, category#36, product#37, amount#38, order_date#39, trim(status#7, None) AS status#40]
#                         +- Project [order_id#33, customer_id#34, city#35, category#36, product#37, amount#38, trim(order_date#6, None) AS order_date#39, status#7]
#                            +- Project [order_id#33, customer_id#34, city#35, category#36, product#37, trim(amount#5, None) AS amount#38, order_date#6, status#7]
#                               +- Project [order_id#33, customer_id#34, city#35, category#36, trim(product#4, None) AS product#37, amount#5, order_date#6, status#7]
#                                  +- Project [order_id#33, customer_id#34, city#35, trim(category#3, None) AS category#36, product#4, amount#5, order_date#6, status#7]
#                                     +- Project [order_id#33, customer_id#34, trim(city#2, None) AS city#35, category#3, product#4, amount#5, order_date#6, status#7]
#                                        +- Project [order_id#33, trim(customer_id#1, None) AS customer_id#34, city#2, category#3, product#4, amount#5, order_date#6, status#7]
#                                           +- Project [trim(order_id#0, None) AS order_id#33, customer_id#1, city#2, category#3, product#4, amount#5, order_date#6, status#7]
#                                              +- LogicalRDD [order_id#0, customer_id#1, city#2, category#3, product#4, amount#5, order_date#6, status#7], false
#
# == Optimized Logical Plan ==
# InMemoryRelation [order_id#33, customer_id#34, city#41, category#42, product#43, amount#44, order_date#45, status#40], StorageLevel(disk, memory, deserialized, 1 replicas)
#    +- AdaptiveSparkPlan isFinalPlan=true
#       +- == Final Plan ==
#          ResultQueryStage 1
#          +- *(3) Filter (isnotnull(status#765) AND (status#765 = Completed))
#             +- SortAggregate(key=[order_id#33], functions=[first(customer_id#34, false), first(city#41, false), first(category#42, false), first(product#43, false), first(amount#44, false), first(order_date#45, false), first(status#40, false)], output=[order_id#33, customer_id#753, city#755, category#757, product#759, amount#761, order_date#763, status#765])
#                +- *(2) Sort [order_id#33 ASC NULLS FIRST], false, 0
#                   +- ShuffleQueryStage 0
#                      +- Exchange hashpartitioning(order_id#33, 200), ENSURE_REQUIREMENTS, [plan_id=1909]
#                         +- SortAggregate(key=[order_id#33], functions=[partial_first(customer_id#34, false), partial_first(city#41, false), partial_first(category#42, false), partial_first(product#43, false), partial_first(amount#44, false), partial_first(order_date#45, false), partial_first(status#40, false)], output=[order_id#33, first#780, valueSet#781, first#782, valueSet#783, first#784, valueSet#785, first#786, valueSet#787, first#788, valueSet#789, first#790, valueSet#791, first#792, valueSet#793])
#                            +- *(1) Sort [order_id#33 ASC NULLS FIRST], false, 0
#                               +- *(1) Project [order_id#33, customer_id#34, city#41, category#42, product#43, CASE WHEN RLIKE(amount#38, ^[0-9]+$) THEN cast(amount#38 as int) END AS amount#44, cast(coalesce(gettimestamp(order_date#39, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM-dd-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM/dd/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) as date) AS order_date#45, status#40]
#                                  +- *(1) Project [trim(order_id#0, None) AS order_id#33, trim(customer_id#1, None) AS customer_id#34, initcap(lower(trim(city#2, None))) AS city#41, initcap(lower(trim(category#3, None))) AS category#42, initcap(lower(trim(product#4, None))) AS product#43, trim(amount#5, None) AS amount#38, trim(order_date#6, None) AS order_date#39, trim(status#7, None) AS status#40]
#                                     +- *(1) Filter CASE WHEN RLIKE(trim(amount#5, None), ^[0-9]+$) THEN isnotnull(cast(trim(amount#5, None) as int)) ELSE false END
#                                        +- *(1) Scan ExistingRDD[order_id#0,customer_id#1,city#2,category#3,product#4,amount#5,order_date#6,status#7]
#       +- == Initial Plan ==
#          Filter (isnotnull(status#765) AND (status#765 = Completed))
#          +- SortAggregate(key=[order_id#33], functions=[first(customer_id#34, false), first(city#41, false), first(category#42, false), first(product#43, false), first(amount#44, false), first(order_date#45, false), first(status#40, false)], output=[order_id#33, customer_id#753, city#755, category#757, product#759, amount#761, order_date#763, status#765])
#             +- Sort [order_id#33 ASC NULLS FIRST], false, 0
#                +- Exchange hashpartitioning(order_id#33, 200), ENSURE_REQUIREMENTS, [plan_id=1868]
#                   +- SortAggregate(key=[order_id#33], functions=[partial_first(customer_id#34, false), partial_first(city#41, false), partial_first(category#42, false), partial_first(product#43, false), partial_first(amount#44, false), partial_first(order_date#45, false), partial_first(status#40, false)], output=[order_id#33, first#780, valueSet#781, first#782, valueSet#783, first#784, valueSet#785, first#786, valueSet#787, first#788, valueSet#789, first#790, valueSet#791, first#792, valueSet#793])
#                      +- Sort [order_id#33 ASC NULLS FIRST], false, 0
#                         +- Project [order_id#33, customer_id#34, city#41, category#42, product#43, CASE WHEN RLIKE(amount#38, ^[0-9]+$) THEN cast(amount#38 as int) END AS amount#44, cast(coalesce(gettimestamp(order_date#39, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM-dd-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM/dd/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) as date) AS order_date#45, status#40]
#                            +- Project [trim(order_id#0, None) AS order_id#33, trim(customer_id#1, None) AS customer_id#34, initcap(lower(trim(city#2, None))) AS city#41, initcap(lower(trim(category#3, None))) AS category#42, initcap(lower(trim(product#4, None))) AS product#43, trim(amount#5, None) AS amount#38, trim(order_date#6, None) AS order_date#39, trim(status#7, None) AS status#40]
#                               +- Filter CASE WHEN RLIKE(trim(amount#5, None), ^[0-9]+$) THEN isnotnull(cast(trim(amount#5, None) as int)) ELSE false END
#                                  +- Scan ExistingRDD[order_id#0,customer_id#1,city#2,category#3,product#4,amount#5,order_date#6,status#7]
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- InMemoryTableScan [order_id#33, customer_id#34, city#41, category#42, product#43, amount#44, order_date#45, status#40]
#       +- InMemoryRelation [order_id#33, customer_id#34, city#41, category#42, product#43, amount#44, order_date#45, status#40], StorageLevel(disk, memory, deserialized, 1 replicas)
#             +- AdaptiveSparkPlan isFinalPlan=true
#                +- == Final Plan ==
#                   ResultQueryStage 1
#                   +- *(3) Filter (isnotnull(status#765) AND (status#765 = Completed))
#                      +- SortAggregate(key=[order_id#33], functions=[first(customer_id#34, false), first(city#41, false), first(category#42, false), first(product#43, false), first(amount#44, false), first(order_date#45, false), first(status#40, false)], output=[order_id#33, customer_id#753, city#755, category#757, product#759, amount#761, order_date#763, status#765])
#                         +- *(2) Sort [order_id#33 ASC NULLS FIRST], false, 0
#                            +- ShuffleQueryStage 0
#                               +- Exchange hashpartitioning(order_id#33, 200), ENSURE_REQUIREMENTS, [plan_id=1909]
#                                  +- SortAggregate(key=[order_id#33], functions=[partial_first(customer_id#34, false), partial_first(city#41, false), partial_first(category#42, false), partial_first(product#43, false), partial_first(amount#44, false), partial_first(order_date#45, false), partial_first(status#40, false)], output=[order_id#33, first#780, valueSet#781, first#782, valueSet#783, first#784, valueSet#785, first#786, valueSet#787, first#788, valueSet#789, first#790, valueSet#791, first#792, valueSet#793])
#                                     +- *(1) Sort [order_id#33 ASC NULLS FIRST], false, 0
#                                        +- *(1) Project [order_id#33, customer_id#34, city#41, category#42, product#43, CASE WHEN RLIKE(amount#38, ^[0-9]+$) THEN cast(amount#38 as int) END AS amount#44, cast(coalesce(gettimestamp(order_date#39, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM-dd-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM/dd/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) as date) AS order_date#45, status#40]
#                                           +- *(1) Project [trim(order_id#0, None) AS order_id#33, trim(customer_id#1, None) AS customer_id#34, initcap(lower(trim(city#2, None))) AS city#41, initcap(lower(trim(category#3, None))) AS category#42, initcap(lower(trim(product#4, None))) AS product#43, trim(amount#5, None) AS amount#38, trim(order_date#6, None) AS order_date#39, trim(status#7, None) AS status#40]
#                                              +- *(1) Filter CASE WHEN RLIKE(trim(amount#5, None), ^[0-9]+$) THEN isnotnull(cast(trim(amount#5, None) as int)) ELSE false END
#                                                 +- *(1) Scan ExistingRDD[order_id#0,customer_id#1,city#2,category#3,product#4,amount#5,order_date#6,status#7]
#                +- == Initial Plan ==
#                   Filter (isnotnull(status#765) AND (status#765 = Completed))
#                   +- SortAggregate(key=[order_id#33], functions=[first(customer_id#34, false), first(city#41, false), first(category#42, false), first(product#43, false), first(amount#44, false), first(order_date#45, false), first(status#40, false)], output=[order_id#33, customer_id#753, city#755, category#757, product#759, amount#761, order_date#763, status#765])
#                      +- Sort [order_id#33 ASC NULLS FIRST], false, 0
#                         +- Exchange hashpartitioning(order_id#33, 200), ENSURE_REQUIREMENTS, [plan_id=1868]
#                            +- SortAggregate(key=[order_id#33], functions=[partial_first(customer_id#34, false), partial_first(city#41, false), partial_first(category#42, false), partial_first(product#43, false), partial_first(amount#44, false), partial_first(order_date#45, false), partial_first(status#40, false)], output=[order_id#33, first#780, valueSet#781, first#782, valueSet#783, first#784, valueSet#785, first#786, valueSet#787, first#788, valueSet#789, first#790, valueSet#791, first#792, valueSet#793])
#                               +- Sort [order_id#33 ASC NULLS FIRST], false, 0
#                                  +- Project [order_id#33, customer_id#34, city#41, category#42, product#43, CASE WHEN RLIKE(amount#38, ^[0-9]+$) THEN cast(amount#38 as int) END AS amount#44, cast(coalesce(gettimestamp(order_date#39, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM-dd-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM/dd/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) as date) AS order_date#45, status#40]
#                                     +- Project [trim(order_id#0, None) AS order_id#33, trim(customer_id#1, None) AS customer_id#34, initcap(lower(trim(city#2, None))) AS city#41, initcap(lower(trim(category#3, None))) AS category#42, initcap(lower(trim(product#4, None))) AS product#43, trim(amount#5, None) AS amount#38, trim(order_date#6, None) AS order_date#39, trim(status#7, None) AS status#40]
#                                        +- Filter CASE WHEN RLIKE(trim(amount#5, None), ^[0-9]+$) THEN isnotnull(cast(trim(amount#5, None) as int)) ELSE false END
#                                           +- Scan ExistingRDD[order_id#0,customer_id#1,city#2,category#3,product#4,amount#5,order_date#6,status#7]

# %% [markdown]
# Repartition data by city and explain why

# %%
df_partitioned=df_clean.repartition(col("city"))
df_partitioned.explain(True)
# Out:
# == Parsed Logical Plan ==
# 'RepartitionByExpression ['city]
# +- Filter (status#40 = Completed)
#    +- Deduplicate [order_id#33]
#       +- Project [order_id#33, customer_id#34, city#41, category#42, product#43, amount#44, cast(coalesce(try_to_timestamp(order_date#39, Some(yyyy-MM-dd), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(dd-MM-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(MM-dd-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(dd/MM/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(MM/dd/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(yyyy/MM/dd), TimestampType, Some(Etc/UTC), false)) as date) AS order_date#45, status#40]
#          +- Filter isnotnull(amount#44)
#             +- Project [order_id#33, customer_id#34, city#41, category#42, product#43, CASE WHEN RLIKE(amount#38, ^[0-9]+$) THEN cast(amount#38 as int) ELSE cast(null as int) END AS amount#44, order_date#39, status#40]
#                +- Project [order_id#33, customer_id#34, city#41, category#42, initcap(lower(product#37)) AS product#43, amount#38, order_date#39, status#40]
#                   +- Project [order_id#33, customer_id#34, city#41, initcap(lower(category#36)) AS category#42, product#37, amount#38, order_date#39, status#40]
#                      +- Project [order_id#33, customer_id#34, initcap(lower(city#35)) AS city#41, category#36, product#37, amount#38, order_date#39, status#40]
#                         +- Project [order_id#33, customer_id#34, city#35, category#36, product#37, amount#38, order_date#39, trim(status#7, None) AS status#40]
#                            +- Project [order_id#33, customer_id#34, city#35, category#36, product#37, amount#38, trim(order_date#6, None) AS order_date#39, status#7]
#                               +- Project [order_id#33, customer_id#34, city#35, category#36, product#37, trim(amount#5, None) AS amount#38, order_date#6, status#7]
#                                  +- Project [order_id#33, customer_id#34, city#35, category#36, trim(product#4, None) AS product#37, amount#5, order_date#6, status#7]
#                                     +- Project [order_id#33, customer_id#34, city#35, trim(category#3, None) AS category#36, product#4, amount#5, order_date#6, status#7]
#                                        +- Project [order_id#33, customer_id#34, trim(city#2, None) AS city#35, category#3, product#4, amount#5, order_date#6, status#7]
#                                           +- Project [order_id#33, trim(customer_id#1, None) AS customer_id#34, city#2, category#3, product#4, amount#5, order_date#6, status#7]
#                                              +- Project [trim(order_id#0, None) AS order_id#33, customer_id#1, city#2, category#3, product#4, amount#5, order_date#6, status#7]
#                                                 +- LogicalRDD [order_id#0, customer_id#1, city#2, category#3, product#4, amount#5, order_date#6, status#7], false
#
# == Analyzed Logical Plan ==
# order_id: string, customer_id: string, city: string, category: string, product: string, amount: int, order_date: date, status: string
# RepartitionByExpression [city#41]
# +- Filter (status#40 = Completed)
#    +- Deduplicate [order_id#33]
#       +- Project [order_id#33, customer_id#34, city#41, category#42, product#43, amount#44, cast(coalesce(try_to_timestamp(order_date#39, Some(yyyy-MM-dd), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(dd-MM-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(MM-dd-yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(dd/MM/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(MM/dd/yyyy), TimestampType, Some(Etc/UTC), false), try_to_timestamp(order_date#39, Some(yyyy/MM/dd), TimestampType, Some(Etc/UTC), false)) as date) AS order_date#45, status#40]
#          +- Filter isnotnull(amount#44)
#             +- Project [order_id#33, customer_id#34, city#41, category#42, product#43, CASE WHEN RLIKE(amount#38, ^[0-9]+$) THEN cast(amount#38 as int) ELSE cast(null as int) END AS amount#44, order_date#39, status#40]
#                +- Project [order_id#33, customer_id#34, city#41, category#42, initcap(lower(product#37)) AS product#43, amount#38, order_date#39, status#40]
#                   +- Project [order_id#33, customer_id#34, city#41, initcap(lower(category#36)) AS category#42, product#37, amount#38, order_date#39, status#40]
#                      +- Project [order_id#33, customer_id#34, initcap(lower(city#35)) AS city#41, category#36, product#37, amount#38, order_date#39, status#40]
#                         +- Project [order_id#33, customer_id#34, city#35, category#36, product#37, amount#38, order_date#39, trim(status#7, None) AS status#40]
#                            +- Project [order_id#33, customer_id#34, city#35, category#36, product#37, amount#38, trim(order_date#6, None) AS order_date#39, status#7]
#                               +- Project [order_id#33, customer_id#34, city#35, category#36, product#37, trim(amount#5, None) AS amount#38, order_date#6, status#7]
#                                  +- Project [order_id#33, customer_id#34, city#35, category#36, trim(product#4, None) AS product#37, amount#5, order_date#6, status#7]
#                                     +- Project [order_id#33, customer_id#34, city#35, trim(category#3, None) AS category#36, product#4, amount#5, order_date#6, status#7]
#                                        +- Project [order_id#33, customer_id#34, trim(city#2, None) AS city#35, category#3, product#4, amount#5, order_date#6, status#7]
#                                           +- Project [order_id#33, trim(customer_id#1, None) AS customer_id#34, city#2, category#3, product#4, amount#5, order_date#6, status#7]
#                                              +- Project [trim(order_id#0, None) AS order_id#33, customer_id#1, city#2, category#3, product#4, amount#5, order_date#6, status#7]
#                                                 +- LogicalRDD [order_id#0, customer_id#1, city#2, category#3, product#4, amount#5, order_date#6, status#7], false
#
# == Optimized Logical Plan ==
# RepartitionByExpression [city#41]
# +- InMemoryRelation [order_id#33, customer_id#34, city#41, category#42, product#43, amount#44, order_date#45, status#40], StorageLevel(disk, memory, deserialized, 1 replicas)
#       +- AdaptiveSparkPlan isFinalPlan=true
#          +- == Final Plan ==
#             ResultQueryStage 1
#             +- *(3) Filter (isnotnull(status#765) AND (status#765 = Completed))
#                +- SortAggregate(key=[order_id#33], functions=[first(customer_id#34, false), first(city#41, false), first(category#42, false), first(product#43, false), first(amount#44, false), first(order_date#45, false), first(status#40, false)], output=[order_id#33, customer_id#753, city#755, category#757, product#759, amount#761, order_date#763, status#765])
#                   +- *(2) Sort [order_id#33 ASC NULLS FIRST], false, 0
#                      +- ShuffleQueryStage 0
#                         +- Exchange hashpartitioning(order_id#33, 200), ENSURE_REQUIREMENTS, [plan_id=1909]
#                            +- SortAggregate(key=[order_id#33], functions=[partial_first(customer_id#34, false), partial_first(city#41, false), partial_first(category#42, false), partial_first(product#43, false), partial_first(amount#44, false), partial_first(order_date#45, false), partial_first(status#40, false)], output=[order_id#33, first#780, valueSet#781, first#782, valueSet#783, first#784, valueSet#785, first#786, valueSet#787, first#788, valueSet#789, first#790, valueSet#791, first#792, valueSet#793])
#                               +- *(1) Sort [order_id#33 ASC NULLS FIRST], false, 0
#                                  +- *(1) Project [order_id#33, customer_id#34, city#41, category#42, product#43, CASE WHEN RLIKE(amount#38, ^[0-9]+$) THEN cast(amount#38 as int) END AS amount#44, cast(coalesce(gettimestamp(order_date#39, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM-dd-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM/dd/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) as date) AS order_date#45, status#40]
#                                     +- *(1) Project [trim(order_id#0, None) AS order_id#33, trim(customer_id#1, None) AS customer_id#34, initcap(lower(trim(city#2, None))) AS city#41, initcap(lower(trim(category#3, None))) AS category#42, initcap(lower(trim(product#4, None))) AS product#43, trim(amount#5, None) AS amount#38, trim(order_date#6, None) AS order_date#39, trim(status#7, None) AS status#40]
#                                        +- *(1) Filter CASE WHEN RLIKE(trim(amount#5, None), ^[0-9]+$) THEN isnotnull(cast(trim(amount#5, None) as int)) ELSE false END
#                                           +- *(1) Scan ExistingRDD[order_id#0,customer_id#1,city#2,category#3,product#4,amount#5,order_date#6,status#7]
#          +- == Initial Plan ==
#             Filter (isnotnull(status#765) AND (status#765 = Completed))
#             +- SortAggregate(key=[order_id#33], functions=[first(customer_id#34, false), first(city#41, false), first(category#42, false), first(product#43, false), first(amount#44, false), first(order_date#45, false), first(status#40, false)], output=[order_id#33, customer_id#753, city#755, category#757, product#759, amount#761, order_date#763, status#765])
#                +- Sort [order_id#33 ASC NULLS FIRST], false, 0
#                   +- Exchange hashpartitioning(order_id#33, 200), ENSURE_REQUIREMENTS, [plan_id=1868]
#                      +- SortAggregate(key=[order_id#33], functions=[partial_first(customer_id#34, false), partial_first(city#41, false), partial_first(category#42, false), partial_first(product#43, false), partial_first(amount#44, false), partial_first(order_date#45, false), partial_first(status#40, false)], output=[order_id#33, first#780, valueSet#781, first#782, valueSet#783, first#784, valueSet#785, first#786, valueSet#787, first#788, valueSet#789, first#790, valueSet#791, first#792, valueSet#793])
#                         +- Sort [order_id#33 ASC NULLS FIRST], false, 0
#                            +- Project [order_id#33, customer_id#34, city#41, category#42, product#43, CASE WHEN RLIKE(amount#38, ^[0-9]+$) THEN cast(amount#38 as int) END AS amount#44, cast(coalesce(gettimestamp(order_date#39, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM-dd-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM/dd/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) as date) AS order_date#45, status#40]
#                               +- Project [trim(order_id#0, None) AS order_id#33, trim(customer_id#1, None) AS customer_id#34, initcap(lower(trim(city#2, None))) AS city#41, initcap(lower(trim(category#3, None))) AS category#42, initcap(lower(trim(product#4, None))) AS product#43, trim(amount#5, None) AS amount#38, trim(order_date#6, None) AS order_date#39, trim(status#7, None) AS status#40]
#                                  +- Filter CASE WHEN RLIKE(trim(amount#5, None), ^[0-9]+$) THEN isnotnull(cast(trim(amount#5, None) as int)) ELSE false END
#                                     +- Scan ExistingRDD[order_id#0,customer_id#1,city#2,category#3,product#4,amount#5,order_date#6,status#7]
#
# == Physical Plan ==
# AdaptiveSparkPlan isFinalPlan=false
# +- Exchange hashpartitioning(city#41, 200), REPARTITION_BY_COL, [plan_id=2138]
#    +- InMemoryTableScan [order_id#33, customer_id#34, city#41, category#42, product#43, amount#44, order_date#45, status#40]
#          +- InMemoryRelation [order_id#33, customer_id#34, city#41, category#42, product#43, amount#44, order_date#45, status#40], StorageLevel(disk, memory, deserialized, 1 replicas)
#                +- AdaptiveSparkPlan isFinalPlan=true
#                   +- == Final Plan ==
#                      ResultQueryStage 1
#                      +- *(3) Filter (isnotnull(status#765) AND (status#765 = Completed))
#                         +- SortAggregate(key=[order_id#33], functions=[first(customer_id#34, false), first(city#41, false), first(category#42, false), first(product#43, false), first(amount#44, false), first(order_date#45, false), first(status#40, false)], output=[order_id#33, customer_id#753, city#755, category#757, product#759, amount#761, order_date#763, status#765])
#                            +- *(2) Sort [order_id#33 ASC NULLS FIRST], false, 0
#                               +- ShuffleQueryStage 0
#                                  +- Exchange hashpartitioning(order_id#33, 200), ENSURE_REQUIREMENTS, [plan_id=1909]
#                                     +- SortAggregate(key=[order_id#33], functions=[partial_first(customer_id#34, false), partial_first(city#41, false), partial_first(category#42, false), partial_first(product#43, false), partial_first(amount#44, false), partial_first(order_date#45, false), partial_first(status#40, false)], output=[order_id#33, first#780, valueSet#781, first#782, valueSet#783, first#784, valueSet#785, first#786, valueSet#787, first#788, valueSet#789, first#790, valueSet#791, first#792, valueSet#793])
#                                        +- *(1) Sort [order_id#33 ASC NULLS FIRST], false, 0
#                                           +- *(1) Project [order_id#33, customer_id#34, city#41, category#42, product#43, CASE WHEN RLIKE(amount#38, ^[0-9]+$) THEN cast(amount#38 as int) END AS amount#44, cast(coalesce(gettimestamp(order_date#39, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM-dd-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM/dd/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) as date) AS order_date#45, status#40]
#                                              +- *(1) Project [trim(order_id#0, None) AS order_id#33, trim(customer_id#1, None) AS customer_id#34, initcap(lower(trim(city#2, None))) AS city#41, initcap(lower(trim(category#3, None))) AS category#42, initcap(lower(trim(product#4, None))) AS product#43, trim(amount#5, None) AS amount#38, trim(order_date#6, None) AS order_date#39, trim(status#7, None) AS status#40]
#                                                 +- *(1) Filter CASE WHEN RLIKE(trim(amount#5, None), ^[0-9]+$) THEN isnotnull(cast(trim(amount#5, None) as int)) ELSE false END
#                                                    +- *(1) Scan ExistingRDD[order_id#0,customer_id#1,city#2,category#3,product#4,amount#5,order_date#6,status#7]
#                   +- == Initial Plan ==
#                      Filter (isnotnull(status#765) AND (status#765 = Completed))
#                      +- SortAggregate(key=[order_id#33], functions=[first(customer_id#34, false), first(city#41, false), first(category#42, false), first(product#43, false), first(amount#44, false), first(order_date#45, false), first(status#40, false)], output=[order_id#33, customer_id#753, city#755, category#757, product#759, amount#761, order_date#763, status#765])
#                         +- Sort [order_id#33 ASC NULLS FIRST], false, 0
#                            +- Exchange hashpartitioning(order_id#33, 200), ENSURE_REQUIREMENTS, [plan_id=1868]
#                               +- SortAggregate(key=[order_id#33], functions=[partial_first(customer_id#34, false), partial_first(city#41, false), partial_first(category#42, false), partial_first(product#43, false), partial_first(amount#44, false), partial_first(order_date#45, false), partial_first(status#40, false)], output=[order_id#33, first#780, valueSet#781, first#782, valueSet#783, first#784, valueSet#785, first#786, valueSet#787, first#788, valueSet#789, first#790, valueSet#791, first#792, valueSet#793])
#                                  +- Sort [order_id#33 ASC NULLS FIRST], false, 0
#                                     +- Project [order_id#33, customer_id#34, city#41, category#42, product#43, CASE WHEN RLIKE(amount#38, ^[0-9]+$) THEN cast(amount#38 as int) END AS amount#44, cast(coalesce(gettimestamp(order_date#39, yyyy-MM-dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd-MM-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM-dd-yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, dd/MM/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, MM/dd/yyyy, TimestampType, try_to_timestamp, Some(Etc/UTC), false), gettimestamp(order_date#39, yyyy/MM/dd, TimestampType, try_to_timestamp, Some(Etc/UTC), false)) as date) AS order_date#45, status#40]
#                                        +- Project [trim(order_id#0, None) AS order_id#33, trim(customer_id#1, None) AS customer_id#34, initcap(lower(trim(city#2, None))) AS city#41, initcap(lower(trim(category#3, None))) AS category#42, initcap(lower(trim(product#4, None))) AS product#43, trim(amount#5, None) AS amount#38, trim(order_date#6, None) AS order_date#39, trim(status#7, None) AS status#40]
#                                           +- Filter CASE WHEN RLIKE(trim(amount#5, None), ^[0-9]+$) THEN isnotnull(cast(trim(amount#5, None) as int)) ELSE false END
#                                              +- Scan ExistingRDD[order_id#0,customer_id#1,city#2,category#3,product#4,amount#5,order_date#6,status#7]

# %% [markdown]
# PHASE 7 — FILE FORMAT OUTPUT
# Write cleaned order-level data to Parquet

# %%
df_clean.write.mode("overwrite").parquet("/data/clean_orders_parquet")

# %% [markdown]
# Write aggregated analytics to ORC

# %%
city_revenue.write.mode("overwrite").orc("/data/city_revenue_orc")

# %% [markdown]
# Read both back and validate schema

# %%
parquet_df=spark.read.parquet("/data/clean_orders_parquet")
orc_df=spark.read.orc("/data/city_revenue_orc")

parquet_df.printSchema()
orc_df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- product: string (nullable = true)
#  |-- amount: integer (nullable = true)
#  |-- order_date: date (nullable = true)
#  |-- status: string (nullable = true)
#
# root
#  |-- city: string (nullable = true)
#  |-- total_revenue: long (nullable = true)

# %% [markdown]
# PHASE 8 — DEBUGGING CHECK
# Explain why this line is incorrect: df = df.filter(df.amount > 30000).show()

# %%
df = df.filter(df.amount > 30000).show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2732565672.py in <cell line: 0>()
# ----> 1 df = df.filter(df.amount > 30000).show()
#
# NameError: name 'df' is not defined

# %% [markdown]
# Write the corrected version

# %%
df = df_clean.filter(col("amount") > 30000)
df.show()
# Out:
# +--------+-----------+---------+-----------+-----------+------+----------+---------+
# |order_id|customer_id|     city|   category|    product|amount|order_date|   status|
# +--------+-----------+---------+-----------+-----------+------+----------+---------+
# |  ORD018|       C008|    Delhi|       Home|     Vacuum| 31000|2024-01-14|Completed|
# |  ORD001|       C001|    Delhi|Electronics|     Laptop| 45000|2024-01-05|Completed|
# |  ORD002|       C002|   Mumbai|Electronics|     Mobile| 32000|2024-01-05|Completed|
# |  ORD017|       C007|Bangalore|Electronics|     Laptop| 51000|2024-01-14|Completed|
# |  ORD016|       C006|   Mumbai|       Home|Airpurifier| 40000|2024-01-13|Completed|
# |  ORD015|       C005|  Chennai|Electronics|     Laptop| 62000|2024-01-13|Completed|
# |  ORD012|       C010|Bangalore|Electronics|     Mobile| 33000|2024-01-11|Completed|
# |  ORD020|       C010|Bangalore|Electronics|     Laptop| 54000|2024-01-15|Completed|
# |  ORD007|       C001|    Delhi|Electronics|     Laptop| 47000|2024-01-09|Completed|
# |  ORD009|       C002|   Mumbai|Electronics|     Laptop| 55000|2024-01-10|Completed|
# |  ORD010|       C008|    Delhi|       Home|Airpurifier| 38000|2024-01-10|Completed|
# +--------+-----------+---------+-----------+-----------+------+----------+---------+
